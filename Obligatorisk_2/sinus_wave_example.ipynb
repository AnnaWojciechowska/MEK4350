# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
frequency = 1  # Frequency in cycles per second
duration = 5  # Duration in seconds
sampling_rate = 1000  # Sampling rate in samples per second
time_data = np.linspace(0, duration, int(sampling_rate * duration), endpoint=False)

sinusoidal_wave = np.sin(2 * np.pi * frequency * time_data)
plt.plot(t, sinusoidal_wave)
plt.title('Sinusoidal Wave - 1 Cycle Per Second')
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
plt.grid(True)
plt.show()

# %%
signal = sinusoidal_wave
signal.mean()
# Out:
# 0.0

# %%
N = len(signal)
std = np.sqrt(sum(np.square(signal))/N)
4*std
# Out:
# 2.82842712474619
